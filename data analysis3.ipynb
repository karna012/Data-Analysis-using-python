# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# '/Users/karan'

# %%
# %cd /Users/karan/Downloads
# Out:
# /Users/karan/Downloads

# %%
pwd
# Out:
# '/Users/karan/Downloads'

# %%
df = pd.read_csv('cars.csv')

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df.shape
# Out:
# (432, 15)

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#       Make               Model    Type Origin DriveTrain      MSRP   Invoice  \
# 30     NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 39     NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 161    NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 173    NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 251  Mazda  RX-8 4dr automatic  Sports   Asia       Rear  $25,700   $23,794
# 252  Mazda     RX-8 4dr manual  Sports   Asia       Rear  $27,200   $25,179
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 30          NaN        NaN         NaN       NaN          NaN     NaN
# 39          NaN        NaN         NaN       NaN          NaN     NaN
# 161         NaN        NaN         NaN       NaN          NaN     NaN
# 173         NaN        NaN         NaN       NaN          NaN     NaN
# 251         1.3        NaN       197.0      18.0         25.0  3053.0
# ...

# %%
df = df.dropna(thresh=9)

# %%
df.isna().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      2
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#       Make               Model    Type Origin DriveTrain      MSRP   Invoice  \
# 251  Mazda  RX-8 4dr automatic  Sports   Asia       Rear  $25,700   $23,794
# 252  Mazda     RX-8 4dr manual  Sports   Asia       Rear  $27,200   $25,179
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 251         1.3        NaN       197.0      18.0         25.0  3053.0
# 252         1.3        NaN       238.0      18.0         24.0  3029.0
#
#      Wheelbase  Length
# 251      106.0   174.0
# 252      106.0   174.0

# %%
df['MSRP'] = df['MSRP'].str.replace('$','').str.replace(',','').astype(int)
# Out:
# /var/folders/4p/p8wlqdd503ngzdh_qs7fn1pw0000gn/T/ipykernel_1407/3288161914.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['MSRP'] = df['MSRP'].str.replace('$','').str.replace(',','').astype(int)
# /var/folders/4p/p8wlqdd503ngzdh_qs7fn1pw0000gn/T/ipykernel_1407/3288161914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MSRP'] = df['MSRP'].str.replace('$','').str.replace(',','').astype(int)

# %%
df.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP             int64
# Invoice         object
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
df1 = df[(df['Type'] == 'Sports') & (df['MSRP'] > 25000) &(df.EngineSize > 1.2) & (df.Horsepower > 196)]

# %%
df1
# Out:
#               Make                                    Model    Type  Origin  \
# 6            Acura                   NSX coupe 2dr manual S  Sports    Asia
# 20            Audi                                 RS 6 4dr  Sports  Europe
# 22            Audi         TT 1.8 Quattro 2dr (convertible)  Sports  Europe
# 23            Audi           TT 3.2 coupe 2dr (convertible)  Sports  Europe
# 43             BMW                             M3 coupe 2dr  Sports  Europe
# 44             BMW                       M3 convertible 2dr  Sports  Europe
# 46             BMW                  Z4 convertible 3.0i 2dr  Sports  Europe
# 63        Cadillac                      XLR convertible 2dr  Sports     USA
# 84       Chevrolet                             Corvette 2dr  Sports     USA
# 85       Chevrolet                 Corvette convertible 2dr  Sports     USA
# 105       Chrysler                            Crossfire 2dr  Sports     USA
# ...

# %%
np.ceil(df.Cylinders.mean())
# Out:
# 6.0

# %%
df.Cylinders.fillna(np.ceil(df.Cylinders.mean()), inplace =True)
# Out:
# /var/folders/4p/p8wlqdd503ngzdh_qs7fn1pw0000gn/T/ipykernel_1407/601377333.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Cylinders.fillna(np.ceil(df.Cylinders.mean()), inplace =True)

# %%
df.isna().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain   MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  36945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755
# ..     ...                      ...    ...     ...        ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210
# 430  Volvo                      V40  Wagon  Europe      Front  26135
# 431  Volvo                     XC70  Wagon  Europe        All  35145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %%
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain   MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  36945  $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820  $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  26990  $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  33195  $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  43755  $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
df[(df['Origin']=="Asia") | (df['Origin']=="Europe")]
# Out:
#       Make                    Model   Type  Origin DriveTrain   MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  36945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755
# ..     ...                      ...    ...     ...        ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210
# 430  Volvo                      V40  Wagon  Europe      Front  26135
# 431  Volvo                     XC70  Wagon  Europe        All  35145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df[df['Origin'].isin(['Asia','Europe'])]
# Out:
#       Make                    Model   Type  Origin DriveTrain   MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  36945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755
# ..     ...                      ...    ...     ...        ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210
# 430  Volvo                      V40  Wagon  Europe      Front  26135
# 431  Volvo                     XC70  Wagon  Europe        All  35145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df[(df["Weight"] < 4000)]
# Out:
#       Make                    Model   Type  Origin DriveTrain   MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  46100
# ..     ...                      ...    ...     ...        ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210
# 430  Volvo                      V40  Wagon  Europe      Front  26135
# 431  Volvo                     XC70  Wagon  Europe        All  35145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df['MPG_City'] = df["MPG_City"].apply(lambda x:x+3)
# Out:
# /var/folders/4p/p8wlqdd503ngzdh_qs7fn1pw0000gn/T/ipykernel_1407/3251387263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MPG_City'] = df["MPG_City"].apply(lambda x:x+3)

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain   MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  36945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755
# ..     ...                      ...    ...     ...        ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210
# 430  Volvo                      V40  Wagon  Europe      Front  26135
# 431  Volvo                     XC70  Wagon  Europe        All  35145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...
