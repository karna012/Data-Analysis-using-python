# %%
pwd
# Out:
# '/Users/karan'

# %%
# %cd /users/karan/Downloads
# Out:
# /Users/karan/Downloads

# %%
pwd
# Out:
# '/Users/karan/Downloads'

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('wd.csv')

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
from datetime import datetime

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df.head(10)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
# 5  1/1/2012 5:00    -1.4              -3.3         87                9
# 6  1/1/2012 6:00    -1.5              -3.1         89                7
# 7  1/1/2012 7:00    -1.4              -3.6         85                7
# 8  1/1/2012 8:00    -1.4              -3.6         85                9
# 9  1/1/2012 9:00    -1.3              -3.1         88               15
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# ...

# %%
def convert_date(date_str):
    """Converts date string to datetime object"""
    try:
        date = datetime.strptime(date_str, '%m/%d/%Y %H:%M')
    except ValueError:
        date = datetime.strptime(date_str, '%d-%m-%Y %H:%M')
    return date

# %%
df['Date'] = df['Date/Time'].apply(convert_date)

# %%
del df['Date/Time']

# %%
df.isna().sum()
# Out:
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# Date                0
# dtype: int64

# %%
df.set_index('Date')
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
# ...                     ...               ...        ...              ...
# 2012-12-31 19:00:00     0.1              -2.7         81               30
# 2012-12-31 20:00:00     0.2              -2.4         83               24
# 2012-12-31 21:00:00    -0.5              -1.5         93               28
# 2012-12-31 22:00:00    -0.2              -1.8         89               28
# 2012-12-31 23:00:00     0.0              -2.1         86               30
#
#                      Visibility_km  Press_kPa               Weather
# ...

# %%
# Assuming your DataFrame is called df
cols = df.columns.tolist()
cols = cols[-1:] + cols[:-1]  # move last column to first
df = df.reindex(columns=cols)

# %%
df
# Out:
#                     Date  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa               Weather
# 0                   4            8.0     101.24                   Fog
# 1                   4            8.0     101.24                   Fog
# ...

# %%
df.count()
# Out:
# Date                8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
df.head()
# Out:
#                  Date  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              8784 non-null   datetime64[ns]
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 549.1+ KB

# %%
list(df['Wind Speed_km/h'].unique())
# Out:
# [4,
#  7,
#  6,
#  9,
#  15,
#  13,
#  20,
#  22,
#  19,
#  24,
#  30,
#  35,
#  39,
#  32,
#  33,
#  26,
#  44,
#  43,
#  48,
#  37,
#  28,
#  17,
#  11,
#  0,
#  83,
#  70,
#  57,
#  46,
#  41,
#  52,
#  50,
#  63,
#  54,
#  2]

# %%
df['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
df['Weather'].str.contains('Clear', case=False).sum()
# Out:
# 3432

# %%
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df[df['Weather']=='Clear']
#df[df['Weather']=='Mainly Clear']
# Out:
#                     Date  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 67   2012-01-03 19:00:00   -16.9             -24.8         50
# 114  2012-01-05 18:00:00    -7.1             -14.4         56
# 115  2012-01-05 19:00:00    -9.2             -15.4         61
# 116  2012-01-05 20:00:00    -9.8             -15.7         62
# 117  2012-01-05 21:00:00    -9.0             -14.8         63
# ...                  ...     ...               ...        ...
# 8646 2012-12-26 06:00:00   -13.4             -14.8         89
# 8698 2012-12-28 10:00:00    -6.1              -8.6         82
# 8713 2012-12-29 01:00:00   -11.9             -13.6         87
# 8714 2012-12-29 02:00:00   -11.8             -13.1         90
# 8756 2012-12-30 20:00:00   -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather
# 67                 24           25.0     101.74   Clear
# 114                11           25.0     100.71   Clear
# ...

# %%
df[df['Weather']=='Mainly Clear']
# Out:
#                     Date  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 36   2012-01-02 12:00:00     1.7              -6.2         56
# 60   2012-01-03 12:00:00   -14.9             -22.6         52
# 61   2012-01-03 13:00:00   -15.1             -22.4         54
# 62   2012-01-03 14:00:00   -14.9             -22.9         50
# 63   2012-01-03 15:00:00   -14.8             -22.2         53
# ...                  ...     ...               ...        ...
# 8753 2012-12-30 17:00:00   -12.1             -15.8         74
# 8754 2012-12-30 18:00:00   -12.6             -16.0         76
# 8755 2012-12-30 19:00:00   -13.4             -16.5         77
# 8757 2012-12-30 21:00:00   -13.8             -16.5         80
# 8758 2012-12-30 22:00:00   -13.7             -16.3         81
#
#       Wind Speed_km/h  Visibility_km  Press_kPa       Weather
# 36                 48           24.1      99.21  Mainly Clear
# 60                 20           24.1     101.34  Mainly Clear
# ...

# %%
df.groupby('Weather').get_group('Clear')
# Out:
#                     Date  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 67   2012-01-03 19:00:00   -16.9             -24.8         50
# 114  2012-01-05 18:00:00    -7.1             -14.4         56
# 115  2012-01-05 19:00:00    -9.2             -15.4         61
# 116  2012-01-05 20:00:00    -9.8             -15.7         62
# 117  2012-01-05 21:00:00    -9.0             -14.8         63
# ...                  ...     ...               ...        ...
# 8646 2012-12-26 06:00:00   -13.4             -14.8         89
# 8698 2012-12-28 10:00:00    -6.1              -8.6         82
# 8713 2012-12-29 01:00:00   -11.9             -13.6         87
# 8714 2012-12-29 02:00:00   -11.8             -13.1         90
# 8756 2012-12-30 20:00:00   -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather
# 67                 24           25.0     101.74   Clear
# 114                11           25.0     100.71   Clear
# ...

# %%
df.groupby('Weather').get_group('Mainly Clear')
# Out:
#                     Date  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 36   2012-01-02 12:00:00     1.7              -6.2         56
# 60   2012-01-03 12:00:00   -14.9             -22.6         52
# 61   2012-01-03 13:00:00   -15.1             -22.4         54
# 62   2012-01-03 14:00:00   -14.9             -22.9         50
# 63   2012-01-03 15:00:00   -14.8             -22.2         53
# ...                  ...     ...               ...        ...
# 8753 2012-12-30 17:00:00   -12.1             -15.8         74
# 8754 2012-12-30 18:00:00   -12.6             -16.0         76
# 8755 2012-12-30 19:00:00   -13.4             -16.5         77
# 8757 2012-12-30 21:00:00   -13.8             -16.5         80
# 8758 2012-12-30 22:00:00   -13.7             -16.3         81
#
#       Wind Speed_km/h  Visibility_km  Press_kPa       Weather
# 36                 48           24.1      99.21  Mainly Clear
# 60                 20           24.1     101.34  Mainly Clear
# ...

# %%
df1=df[df['Wind Speed_km/h']== 4]

# %%
df1.to_csv('4km.csv', index=False)

# %%
# download the CSV file
from IPython.display import FileLink
display(FileLink('4km.csv'))
# Out:
# /Users/karan/Downloads/4km.csv

# %%
df2 = pd.read_csv('4km.csv')

# %%
from IPython.display import HTML

# %%
import base64

# %%
csv_file = open('4km.csv', 'rb').read()
b64_csv = base64.b64encode(csv_file).decode('utf-8')
href = f'<a href="data:file/csv;base64,{b64_csv}" download="4km.csv">Download CSV file</a>'
HTML(href)
# Out:
# <a href="data:file/csv;base64,..." download="4km.csv">Download CSV file</a>

# %%
df.isna().sum()
# Out:
# Date                0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df=df.rename(columns={'Weather':'weather_condition'})

# %%
df=df.rename(columns={'Temp_C': 'Temp'})

# %%
df
# Out:
#                     Date  Temp  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0    2012-01-01 00:00:00  -1.8              -3.9         86                4
# 1    2012-01-01 01:00:00  -1.8              -3.7         87                4
# 2    2012-01-01 02:00:00  -1.8              -3.4         89                7
# 3    2012-01-01 03:00:00  -1.5              -3.2         88                6
# 4    2012-01-01 04:00:00  -1.5              -3.3         88                7
# ...                  ...   ...               ...        ...              ...
# 8779 2012-12-31 19:00:00   0.1              -2.7         81               30
# 8780 2012-12-31 20:00:00   0.2              -2.4         83               24
# 8781 2012-12-31 21:00:00  -0.5              -1.5         93               28
# 8782 2012-12-31 22:00:00  -0.2              -1.8         89               28
# 8783 2012-12-31 23:00:00   0.0              -2.1         86               30
#
# ...

# %%
df = df.rename(columns={'weather_condition':'weather'})

# %%
df
# Out:
#                     Date  Temp  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0    2012-01-01 00:00:00  -1.8              -3.9         86                4
# 1    2012-01-01 01:00:00  -1.8              -3.7         87                4
# 2    2012-01-01 02:00:00  -1.8              -3.4         89                7
# 3    2012-01-01 03:00:00  -1.5              -3.2         88                6
# 4    2012-01-01 04:00:00  -1.5              -3.3         88                7
# ...                  ...   ...               ...        ...              ...
# 8779 2012-12-31 19:00:00   0.1              -2.7         81               30
# 8780 2012-12-31 20:00:00   0.2              -2.4         83               24
# 8781 2012-12-31 21:00:00  -0.5              -1.5         93               28
# 8782 2012-12-31 22:00:00  -0.2              -1.8         89               28
# 8783 2012-12-31 23:00:00   0.0              -2.1         86               30
#
# ...

# %%
df['Visibility_km'].describe()
# Out:
# count    8784.000000
# mean       27.664447
# std        12.622688
# min         0.200000
# 25%        24.100000
# 50%        25.000000
# 75%        25.000000
# max        48.300000
# Name: Visibility_km, dtype: float64

# %%
df.describe()
# Out:
#               Temp  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
variance = df['Rel Hum_%'].var()
Mean = df['Rel Hum_%'].mean()
Std_Dev = df['Rel Hum_%'].std()

# %%
Std_Dev = df['Rel Hum_%'].std()
Mean + Std_Dev
# Out:
# 84.35057545914759

# %%
plt.plot(df['Rel Hum_%'], 'm')
plt.axhline(Mean, color='red', label='Mean')
plt.axhline(Mean + Std_Dev, color='green', linestyle='dashed', label='Std Dev')
plt.axhline(Mean - Std_Dev, color='green', linestyle='dashed')
plt.axhline(Mean + 2*Std_Dev, color='orange', linestyle='dashed', label='2 Std Dev')
plt.axhline(Mean - 2*Std_Dev, color='orange', linestyle='dashed')
plt.axhline(Mean + 3*Std_Dev, color='purple', linestyle='dashed', label='3 Std Dev')
plt.axhline(Mean - 3*Std_Dev, color='purple', linestyle='dashed')
plt.title('Rel Hum_% Scatter Plot')
plt.xlabel('Index')
plt.ylabel('Rel Hum_%')
plt.legend()
plt.show()

# %%
df.head()
# Out:
#                  Date  Temp  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00  -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00  -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00  -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00  -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00  -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.weather.unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
df.groupby('weather').get_group('Snow')
# Out:
#                     Date  Temp  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55   2012-01-03 07:00:00 -14.0             -19.5         63               19
# 84   2012-01-04 12:00:00 -13.7             -21.7         51               11
# 86   2012-01-04 14:00:00 -11.3             -19.0         53                7
# 87   2012-01-04 15:00:00 -10.2             -16.3         61               11
# 88   2012-01-04 16:00:00  -9.4             -15.5         61               13
# ...                  ...   ...               ...        ...              ...
# 8779 2012-12-31 19:00:00   0.1              -2.7         81               30
# 8780 2012-12-31 20:00:00   0.2              -2.4         83               24
# 8781 2012-12-31 21:00:00  -0.5              -1.5         93               28
# 8782 2012-12-31 22:00:00  -0.2              -1.8         89               28
# 8783 2012-12-31 23:00:00   0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa weather
# ...

# %%
df[df['weather']=='Snow']
# Out:
#                     Date  Temp  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55   2012-01-03 07:00:00 -14.0             -19.5         63               19
# 84   2012-01-04 12:00:00 -13.7             -21.7         51               11
# 86   2012-01-04 14:00:00 -11.3             -19.0         53                7
# 87   2012-01-04 15:00:00 -10.2             -16.3         61               11
# 88   2012-01-04 16:00:00  -9.4             -15.5         61               13
# ...                  ...   ...               ...        ...              ...
# 8779 2012-12-31 19:00:00   0.1              -2.7         81               30
# 8780 2012-12-31 20:00:00   0.2              -2.4         83               24
# 8781 2012-12-31 21:00:00  -0.5              -1.5         93               28
# 8782 2012-12-31 22:00:00  -0.2              -1.8         89               28
# 8783 2012-12-31 23:00:00   0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa weather
# ...

# %%
df[df['weather'].str.contains('Snow' ,case=False)]
# Out:
#                     Date  Temp  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41   2012-01-02 17:00:00  -2.1              -9.5         57               22
# 44   2012-01-02 20:00:00  -5.6             -13.4         54               24
# 45   2012-01-02 21:00:00  -5.8             -12.8         58               26
# 47   2012-01-02 23:00:00  -7.4             -14.1         59               17
# 48   2012-01-03 00:00:00  -9.0             -16.0         57               28
# ...                  ...   ...               ...        ...              ...
# 8779 2012-12-31 19:00:00   0.1              -2.7         81               30
# 8780 2012-12-31 20:00:00   0.2              -2.4         83               24
# 8781 2012-12-31 21:00:00  -0.5              -1.5         93               28
# 8782 2012-12-31 22:00:00  -0.2              -1.8         89               28
# 8783 2012-12-31 23:00:00   0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa       weather
# ...

# %%
df[df.weather.str.contains('Fog')]
# Out:
#                     Date  Temp  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0    2012-01-01 00:00:00  -1.8              -3.9         86                4
# 1    2012-01-01 01:00:00  -1.8              -3.7         87                4
# 2    2012-01-01 02:00:00  -1.8              -3.4         89                7
# 3    2012-01-01 03:00:00  -1.5              -3.2         88                6
# 4    2012-01-01 04:00:00  -1.5              -3.3         88                7
# ...                  ...   ...               ...        ...              ...
# 8739 2012-12-30 03:00:00  -9.1             -10.4         90               11
# 8740 2012-12-30 04:00:00  -9.3             -10.6         90               13
# 8741 2012-12-30 05:00:00  -9.1             -10.4         90               11
# 8742 2012-12-30 06:00:00  -9.3             -10.8         89               17
# 8770 2012-12-31 10:00:00  -7.4              -8.9         89                4
#
# ...

# %%
df.weather.value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df.head()
# Out:
#                  Date  Temp  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00  -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00  -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00  -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00  -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00  -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df[(df['Wind Speed_km/h'] > 24) & (df['Visibility_km'] == 25)]
# Out:
#                     Date  Temp  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23   2012-01-01 23:00:00   5.3               2.0         79               30
# 24   2012-01-02 00:00:00   5.2               1.5         77               35
# 25   2012-01-02 01:00:00   4.6               0.0         72               39
# 26   2012-01-02 02:00:00   3.9              -0.9         71               32
# 27   2012-01-02 03:00:00   3.7              -1.5         69               33
# ...                  ...   ...               ...        ...              ...
# 8705 2012-12-28 17:00:00  -8.6             -12.0         76               26
# 8753 2012-12-30 17:00:00 -12.1             -15.8         74               28
# 8755 2012-12-30 19:00:00 -13.4             -16.5         77               26
# 8759 2012-12-30 23:00:00 -12.1             -15.1         78               28
# 8760 2012-12-31 00:00:00 -11.1             -14.4         77               26
#
# ...

# %%
df.groupby('weather').mean()
# Out:
# /var/folders/4p/p8wlqdd503ngzdh_qs7fn1pw0000gn/T/ipykernel_1359/73590551.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('weather').mean()
#                                               Temp  Dew Point Temp_C  \
# weather
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# ...

# %%
(df.groupby('weather').min()).drop('Date', axis=1)
# Out:
#                                          Temp  Dew Point Temp_C  Rel Hum_%  \
# weather
# Clear                                   -23.3             -28.5         20
# Cloudy                                  -21.4             -26.8         18
# Drizzle                                   1.1              -0.2         74
# Drizzle,Fog                               0.0              -1.6         85
# Drizzle,Ice Pellets,Fog                   0.4              -0.7         92
# Drizzle,Snow                              0.9               0.1         92
# Drizzle,Snow,Fog                          0.3              -0.1         92
# Fog                                     -16.0             -17.2         80
# Freezing Drizzle                         -9.0             -12.2         78
# Freezing Drizzle,Fog                     -6.4              -9.0         82
# Freezing Drizzle,Haze                    -5.8              -8.3         81
# ...

# %%
df[(df.weather == 'Clear') | (df.Visibility_km > 40 )]
# Out:
#                     Date  Temp  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67   2012-01-03 19:00:00 -16.9             -24.8         50               24
# 106  2012-01-05 10:00:00  -6.0             -10.0         73               17
# 107  2012-01-05 11:00:00  -5.6             -10.2         70               22
# 108  2012-01-05 12:00:00  -4.7              -9.6         69               20
# 109  2012-01-05 13:00:00  -4.4              -9.7         66               26
# ...                  ...   ...               ...        ...              ...
# 8749 2012-12-30 13:00:00 -12.4             -16.2         73               37
# 8750 2012-12-30 14:00:00 -11.8             -16.1         70               37
# 8751 2012-12-30 15:00:00 -11.3             -15.6         70               32
# 8752 2012-12-30 16:00:00 -11.4             -15.5         72               26
# 8756 2012-12-30 20:00:00 -13.8             -16.5         80               24
#
# ...

# %%
df[((df.weather =='Clear') & (df['Rel Hum_%'] > 50)) | (df.Visibility_km > 40)]
# Out:
#                     Date  Temp  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106  2012-01-05 10:00:00  -6.0             -10.0         73               17
# 107  2012-01-05 11:00:00  -5.6             -10.2         70               22
# 108  2012-01-05 12:00:00  -4.7              -9.6         69               20
# 109  2012-01-05 13:00:00  -4.4              -9.7         66               26
# 110  2012-01-05 14:00:00  -5.1             -10.7         65               22
# ...                  ...   ...               ...        ...              ...
# 8749 2012-12-30 13:00:00 -12.4             -16.2         73               37
# 8750 2012-12-30 14:00:00 -11.8             -16.1         70               37
# 8751 2012-12-30 15:00:00 -11.3             -15.6         70               32
# 8752 2012-12-30 16:00:00 -11.4             -15.5         72               26
# 8756 2012-12-30 20:00:00 -13.8             -16.5         80               24
#
# ...
